# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('nike_data_2022_09.csv')

# %%
df.head()
# Out:
#    index                                                url  \
# 0      0  https://www.nike.com/t/dri-fit-team-minnesota-...
# 1      1  https://www.nike.com/t/club-américa-womens-dri...
# 2      2  https://www.nike.com/t/sportswear-swoosh-mens-...
# 3      3  https://www.nike.com/t/dri-fit-one-luxe-big-ki...
# 4      4  https://www.nike.com/t/paris-saint-germain-rep...
#
#                                       name  \
# 0  Nike Dri-FIT Team (MLB Minnesota Twins)
# 1                             Club América
# 2                   Nike Sportswear Swoosh
# 3                    Nike Dri-FIT One Luxe
# 4    Paris Saint-Germain Repel Academy AWF
#
#                                            sub_title brand     model  \
# 0                          Men's Long-Sleeve T-Shirt  Nike  14226571
# 1           Women's Nike Dri-FIT Soccer Jersey Dress  Nike  13814665
# 2                                     Men's Overalls  Nike  13015648
# ...

# %%
df.tail()
# Out:
#      index                                                url  \
# 107    107  https://www.nike.com/t/air-jordan-xxxv-low-ds-...
# 108    108  https://www.nike.com/t/dri-fit-ucla-mens-polo-...
# 109    109  https://www.nike.com/t/jordan-big-kids-boys-fu...
# 110    110  https://www.nike.com/t/los-angeles-rams-vapor-...
# 111    111  https://www.nike.com/t/team-first-houston-astr...
#
#                                                   name  \
# 107                          Air Jordan XXXV Low DS PF
# 108                        Nike College Dri-FIT (UCLA)
# 109                                             Jordan
# 110  NFL Los Angeles Rams Nike Vapor Untouchable (M...
# 111               Nike Team First (MLB Houston Astros)
#
#                              sub_title brand     model  \
# 107                   Basketball Shoes  Nike  13167172
# 108                         Men's Polo  Nike  14045780
# 109  Big Kids' (Boys') Full-Zip Jacket  Nike  13847339
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            112 non-null    int64
#  1   url              112 non-null    object
#  2   name             112 non-null    object
#  3   sub_title        112 non-null    object
#  4   brand            112 non-null    object
#  5   model            112 non-null    int64
#  6   color            110 non-null    object
#  7   price            112 non-null    float64
#  8   currency         112 non-null    object
#  9   availability     108 non-null    object
#  10  description      112 non-null    object
#  11  raw_description  112 non-null    object
#  12  avg_rating       23 non-null     float64
#  13  review_count     23 non-null     float64
#  14  images           108 non-null    object
#  15  available_sizes  56 non-null     object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=112, step=1)

# %%
df.columns
# Out:
# Index(['index', 'url', 'name', 'sub_title', 'brand', 'model', 'color', 'price',
#        'currency', 'availability', 'description', 'raw_description',
#        'avg_rating', 'review_count', 'images', 'available_sizes', 'uniq_id',
#        'scraped_at'],
#       dtype='object')

# %%
df.T   #transpose
# Out:
#                                                                0    \
# index                                                            0
# url              https://www.nike.com/t/dri-fit-team-minnesota-...
# name                       Nike Dri-FIT Team (MLB Minnesota Twins)
# sub_title                                Men's Long-Sleeve T-Shirt
# brand                                                         Nike
# model                                                     14226571
# color                                                         Navy
# price                                                         40.0
# currency                                                       USD
# availability                                               InStock
# description      SWEAT-WICKING COMFORT.The Nike Dri-FIT Team (M...
# raw_description  <div class="pi-pdpmainbody"><p><b class="headl...
# avg_rating                                                     NaN
# ...

# %%
df.shape
# Out:
# (112, 18)

# %%
df.isnull()
# Out:
#      index    url   name  sub_title  brand  model  color  price  currency  \
# 0    False  False  False      False  False  False  False  False     False
# 1    False  False  False      False  False  False  False  False     False
# 2    False  False  False      False  False  False  False  False     False
# 3    False  False  False      False  False  False  False  False     False
# 4    False  False  False      False  False  False  False  False     False
# ..     ...    ...    ...        ...    ...    ...    ...    ...       ...
# 107  False  False  False      False  False  False  False  False     False
# 108  False  False  False      False  False  False  False  False     False
# 109  False  False  False      False  False  False  False  False     False
# 110  False  False  False      False  False  False  False  False     False
# 111  False  False  False      False  False  False  False  False     False
#
#      availability  description  raw_description  avg_rating  review_count  \
# ...

# %%
df.isnull().sum()
# Out:
# index               0
# url                 0
# name                0
# sub_title           0
# brand               0
# model               0
# color               2
# price               0
# currency            0
# availability        4
# description         0
# raw_description     0
# avg_rating         89
# review_count       89
# images              4
# available_sizes    56
# uniq_id             0
# scraped_at          0
# dtype: int64

# %%
df.to_numpy()
# Out:
# array([[0,
#         'https://www.nike.com/t/dri-fit-team-minnesota-twins-mens-long-sleeve-t-shirt-6Wdjql',
#         'Nike Dri-FIT Team (MLB Minnesota Twins)', ...,
#         'S | M | L | XL | 2XL', 'c3229e54-aa58-5fdd-9f71-fbe66366b2b2',
#         '20/09/2022 23:32:28'],
#        [1,
#         'https://www.nike.com/t/club-américa-womens-dri-fit-soccer-jersey-dress-MP2NrK',
#         'Club América', ..., 'L (12–14)',
#         'f8ebb2ed-17ae-5719-b750-5ea3ec69b75c', '20/09/2022 23:32:40'],
#        [2,
#         'https://www.nike.com/t/sportswear-swoosh-mens-overalls-rKsQ2c',
#         'Nike Sportswear Swoosh', ..., nan,
#         '88120081-e6cb-5399-b9dc-a2d3d5dd5206', '20/09/2022 23:33:16'],
#        ...,
#        [109,
#         'https://www.nike.com/t/jordan-big-kids-boys-full-zip-jacket-896nRz',
#         'Jordan', ..., nan, '0a73c673-3f1e-5761-91aa-a10db4092973',
#         '20/09/2022 23:52:48'],
#        [110,
# ...

# %%
df.mean()
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_2952\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# index           5.550000e+01
# model           9.298439e+07
# price           6.150625e+01
# avg_rating      4.773913e+00
# review_count    3.139130e+01
# dtype: float64

# %%
df.mean(1)
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_2952\3808537418.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(1)
# 0      4.742204e+06
# 1      2.762952e+06
# 2      2.603161e+06
# 3      4.603274e+06
# 4      4.442496e+06
#            ...
# 107    4.389148e+06
# 108    4.681979e+06
# 109    4.615841e+06
# 110    4.669055e+06
# 111    4.742189e+06
# Length: 112, dtype: float64

# %%
df.describe()
# Out:
#             index         model       price  avg_rating  review_count
# count  112.000000  1.120000e+02  112.000000   23.000000     23.000000
# mean    55.500000  9.298439e+07   61.506250    4.773913     31.391304
# std     32.475632  2.698557e+08   39.887738    0.336043     72.942530
# min      0.000000  1.013351e+07    9.970000    3.800000      1.000000
# 25%     27.750000  1.329489e+07   31.720000    4.750000      1.000000
# 50%     55.500000  1.389103e+07   45.000000    4.800000      5.000000
# 75%     83.250000  1.406539e+07   85.242500    5.000000     13.000000
# max    111.000000  1.007648e+09  175.000000    5.000000    316.000000

# %%
import missingno as mn
mn.bar(df)
# Out:
# <AxesSubplot:>

# %%
mn.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
mn.dendrogram(df)
# Out:
# <AxesSubplot:>

# %%
mn.matrix(df)
# Out:
# <AxesSubplot:>

# %%
sns.displot(df['price'])

# %%
sns.distplot(df['price'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['price'], hist_kws=dict(linewidth=1, color='r'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['index'], hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='index', ylabel='Density'>

# %%
x,y= plt.subplots(figsize = (10,10))

sns.distplot(df['index'], hist= False, ax= y)
y.axvline(df['index'].mean(),color='g', ls='--')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x,y= plt.subplots(figsize = (10,10))

sns.distplot(df['index'], hist= True, color='r',  ax= y)
y.axvline(df['index'].mean(),color='g', ls='--')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
unique_name=[]
for i in df.columns:
    x=df[i].value_counts().count()
    unique_name.append(x)

pd.DataFrame(unique_name, index=df.columns, columns =["total unique value"])
# Out:
#                  total unique value
# index                           112
# url                             112
# name                             96
# sub_title                        80
# brand                             1
# model                           112
# color                            76
# price                            63
# currency                          1
# availability                      2
# description                     112
# raw_description                 112
# avg_rating                        7
# review_count                     11
# images                          108
# available_sizes                  35
# uniq_id                         112
# scraped_at                      108
